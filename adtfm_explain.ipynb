# %%
from adtfm import ADTFM_AT_Model_Image
import torch
from torch import nn
from datasets import MixedImgDataset
from torchvision import transforms
import numpy as np
import matplotlib.pyplot as plt

# %%
# Define transforms
transform = transforms.Compose([
    transforms.Resize((256, 256)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# %%
# Create dataset
dataset = MixedImgDataset(root_dir='./data/MixedImg', transform=transform)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
model = ADTFM_AT_Model_Image(
    in_channels=3,
    cnn_out_channels=128,
    hidden_size=256,
    num_layers=2,
    num_classes=3
).to(device)

# %%
model.load_state_dict(torch.load('./adt_model.pth', weights_only=True))
model.eval()
# Out:
# ADTFM_AT_Model_Image(
#   (cnn): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (4): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (5): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (8): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (10): ReLU()
#   )
#   (adaptive_pool): AdaptiveAvgPool2d(output_size=(8, None))
#   (rnn): ADTFM_RNN(
#     (cells): ModuleList(
#       (0): ADTFMCell(
#         (W_i): Linear(in_features=1024, out_features=256, bias=True)
#         (U_i): Linear(in_features=256, out_features=256, bias=True)
#         (W_f): Linear(in_features=1024, out_features=256, bias=True)
#         (U_f): Linear(in_features=256, out_features=256, bias=True)
#         (W_o): Linear(in_features=1024, out_features=256, bias=True)
#         (U_o): Linear(in_features=256, out_features=256, bias=True)
#         (W_g): Linear(in_features=1024, out_features=256, bias=True)
#         (U_g): Linear(in_features=256, out_features=256, bias=True)
#         (W_a): Linear(in_features=256, out_features=256, bias=True)
#         (W_b): Linear(in_features=256, out_features=256, bias=True)
#         (W_f_ste): Linear(in_features=1024, out_features=256, bias=True)
#         (U_f_ste): Linear(in_features=256, out_features=256, bias=True)
#         (W_f_tim): Linear(in_features=1024, out_features=256, bias=True)
#         (U_f_tim): Linear(in_features=256, out_features=256, bias=True)
#         (W_f_fre): Linear(in_features=1024, out_features=256, bias=True)
#         (U_f_fre): Linear(in_features=256, out_features=256, bias=True)
#         (fc_out): Linear(in_features=256, out_features=256, bias=True)
#       )
#       (1): ADTFMCell(
#         (W_i): Linear(in_features=256, out_features=256, bias=True)
#         (U_i): Linear(in_features=256, out_features=256, bias=True)
#         (W_f): Linear(in_features=256, out_features=256, bias=True)
#         (U_f): Linear(in_features=256, out_features=256, bias=True)
#         (W_o): Linear(in_features=256, out_features=256, bias=True)
#         (U_o): Linear(in_features=256, out_features=256, bias=True)
#         (W_g): Linear(in_features=256, out_features=256, bias=True)
#         (U_g): Linear(in_features=256, out_features=256, bias=True)
#         (W_a): Linear(in_features=256, out_features=256, bias=True)
#         (W_b): Linear(in_features=256, out_features=256, bias=True)
#         (W_f_ste): Linear(in_features=256, out_features=256, bias=True)
#         (U_f_ste): Linear(in_features=256, out_features=256, bias=True)
#         (W_f_tim): Linear(in_features=256, out_features=256, bias=True)
#         (U_f_tim): Linear(in_features=256, out_features=256, bias=True)
#         (W_f_fre): Linear(in_features=256, out_features=256, bias=True)
#         (U_f_fre): Linear(in_features=256, out_features=256, bias=True)
#         (fc_out): Linear(in_features=256, out_features=256, bias=True)
#       )
#     )
#   )
#   (attention): Attention(
#     (attention_fc): Linear(in_features=256, out_features=256, bias=True)
#   )
#   (classifier): Linear(in_features=256, out_features=3, bias=True)
# )

# %%
dataset[0][0].shape
# Out:
# torch.Size([3, 256, 256])

# %%
# Create a dataloader to get all images
dataloader = torch.utils.data.DataLoader(dataset, batch_size=len(dataset), shuffle=False)

# Get all images in a batch
all_images_bchw, all_labels = next(iter(dataloader))

# Print the shape to confirm
print(f"All images shape: {all_images_bchw.shape}")
print(f"All labels shape: {all_labels.shape}")

# If needed, move to device
all_images_bchw = all_images_bchw.to(device)
all_labels = all_labels.to(device)
# Out:
# All images shape: torch.Size([42, 3, 256, 256])
# All labels shape: torch.Size([42])

# %%
all_images_bhwc = all_images_bchw.permute(0, 2, 3, 1)  # Convert to BHW(C)

# %%
def shap_predict(images_nhwc):
    """
    Predict the class of an image using the model.
    :param image_nhwc: Image in NHWC format
    :return: Predicted class
    """
    # Move to device
    images_nhwc = torch.tensor(images_nhwc).to(device)
    images_nchw = images_nhwc.permute(0, 3, 1, 2)  # Convert to NCHW format
    
    # Forward pass
    with torch.no_grad():
        output = model(images_nchw)
    
    return output

# %%
import shap

# %%
# 定义 mask，遮盖输入图像上的局部区域
masker_blur = shap.maskers.Image("blur(128, 128)", all_images_bhwc[0].shape)

# %%
explainer = shap.Explainer(shap_predict, masker_blur, output_names=['Disturbance', 'IF', 'Normal'])

# %%
shap_values = explainer(all_images_bhwc, max_evals=1000, batch_size=50, outputs=shap.Explanation.argsort.flip[:3])
# Out:
# PartitionExplainer explainer: 43it [01:19,  2.15s/it]

# %%
def denorm_func(x):
    """
    Denormalize the image tensor.
    :param x: Image tensor
    :return: Denormalized image
    """
    x = x * np.array([0.229, 0.224, 0.225]) + np.array([0.485, 0.456, 0.406])
    return x

# %%
shap_values.data = denorm_func(shap_values.data.cpu().numpy()) # (42, 256, 256, 3)
shap_values.values = [val for val in np.transpose(shap_values.values, (4,0,1,2,3))] # shap值热力图

# %%
shap.image_plot(shap_values = shap_values.values,
                pixel_values = shap_values.data,
                labels = shap_values.output_names,
                hspace = 'auto',
                show = True)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-4.053115898461357e-09..1.0000000236034394].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-4.053115898461357e-09..1.0000000236034394].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-4.053115898461357e-09..1.0000000236034394].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-4.053115898461357e-09..1.0000000236034394].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.011764705657959007..1.0000000236034394].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-4.053115898461357e-09..1.0000000236034394].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-4.053115898461357e-09..1.0000000236034394].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-4.053115898461357e-09..1.0000000236034394].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.011764705657959007..1.0000000236034394].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-4.053115898461357e-09..1.0000000236034394].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.011764705657959007..1.0000000236034394].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-4.053115898461357e-09..1.0000000236034394].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-4.053115898461357e-09..1.0000000236034394].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-4.053115898461357e-09..1.0000000236034394].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-4.053115898461357e-09..1.0000000236034394].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-4.053115898461357e-09..1.0000000236034394].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-4.053115898461357e-09..1.0000000236034394].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-4.053115898461357e-09..1.0000000236034394].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-4.053115898461357e-09..1.0000000236034394].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-4.053115898461357e-09..1.0000000236034394].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-4.053115898461357e-09..1.0000000236034394].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-4.053115898461357e-09..1.0000000236034394].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-4.053115898461357e-09..1.0000000236034394].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [2.7418136649970393e-09..1.0000000236034394].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-4.053115898461357e-09..1.0000000236034394].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-4.053115898461357e-09..1.0000000236034394].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [2.7418136649970393e-09..1.0000000236034394].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-4.053115898461357e-09..1.0000000236034394].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-4.053115898461357e-09..1.0000000236034394].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-4.053115898461357e-09..1.0000000236034394].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-4.053115898461357e-09..1.0000000236034394].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-4.053115898461357e-09..1.0000000236034394].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-4.053115898461357e-09..1.0000000236034394].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-4.053115898461357e-09..1.0000000236034394].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-4.053115898461357e-09..1.0000000236034394].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-4.053115898461357e-09..1.0000000236034394].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-4.053115898461357e-09..1.0000000236034394].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-4.053115898461357e-09..1.0000000236034394].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-4.053115898461357e-09..1.0000000236034394].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-4.053115898461357e-09..1.0000000236034394].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-4.053115898461357e-09..1.0000000236034394].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-4.053115898461357e-09..1.0000000236034394].
